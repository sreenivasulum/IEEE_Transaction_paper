# %%
'''
Created on 11-May-2015

@author: Koustav
'''

import sys
import re
import codecs
import string
import os
import numpy as np
from textblob import *
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn import svm
from sklearn.svm import *
from sklearn.linear_model import *
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import metrics
from sklearn import cross_validation
import gzip
from happyfuntokenizing import *
import numpy as np
from sklearn.naive_bayes import *
#from happyfuntokenizing import *

lmtzr = WordNetLemmatizer()
mycompile = lambda pat:  re.compile(pat,  re.UNICODE)

PRONOUN_PATH = '/home/sreenu/Desktop/rudra/koustav_phdthesis_2018-master/Lexical_resources/classifier_dictionary/english_pronoun.txt'
WHWORD_PATH = '/home/sreenu/Desktop/rudra/koustav_phdthesis_2018-master/Lexical_resources/classifier_dictionary/english_whwords.txt'
SLANG_PATH = '/home/sreenu/Desktop/rudra/koustav_phdthesis_2018-master/Lexical_resources/classifier_dictionary/english_swear.txt'
INTENSIFIER_PATH = '/home/sreenu/Desktop/rudra/koustav_phdthesis_2018-master/Lexical_resources/classifier_dictionary/english_intensifier.txt'
SUBJECTIVE_PATH = '/home/sreenu/Desktop/rudra/koustav_phdthesis_2018-master/Lexical_resources/classifier_dictionary/subjclueslen1-HLTEMNLP05.tff'
EVENT_PATH = '/home/sreenu/Desktop/rudra/koustav_phdthesis_2018-master/Lexical_resources/classifier_dictionary/english_nonsituational_phrase.txt'
MODAL_VERB_PATH = '/home/sreenu/Desktop/rudra/koustav_phdthesis_2018-master/Lexical_resources/classifier_dictionary/english_modal_verb.txt'
RELIGION_PATH = '/home/sreenu/Desktop/rudra/koustav_phdthesis_2018-master/Lexical_resources/classifier_dictionary/communal_race.txt'
#NONSIT_PATH = 'Common_nonsituational_word.txt'
#OPINION_HASHTAG_PATH = '/home/krudra/twitter_code/shared/language_overlap/code_mix_pitch/devanagari/devanagari_hashtag_opinion.txt'
#MENTION_PATH = '/home/krudra/twitter_code/shared/language_overlap/code_mix_pitch/devanagari/news_mention.txt'

#TRAIN1 = '../classification_4.3/fragmented_train_data/hydb_fragment_train.txt'
#TRAIN2 = '../classification_4.3/fragmented_train_data/utkd_fragment_train.txt'
#TRAIN3 = '../classification_4.3/fragmented_train_data/sandy_hook_fragment_train.txt'
#TRAIN4 = '../classification_4.3/fragmented_train_data/hagupit_fragment_train.txt'

TRAIN1 = '/home/sreenu/Desktop/rudra/koustav_phdthesis_2018-master/Chapter_3/classification/fragmented_train_data/hydb_fragment_train.txt'
TRAIN2 = '/home/sreenu/Desktop/rudra/koustav_phdthesis_2018-master/Chapter_3/classification/fragmented_train_data/utkd_fragment_train.txt'
TRAIN3 = '/home/sreenu/Desktop/rudra/koustav_phdthesis_2018-master/Chapter_3/classification/fragmented_train_data/sandy_hook_fragment_train.txt'
TRAIN4 = '/home/sreenu/Desktop/rudra/koustav_phdthesis_2018-master/Chapter_3/classification/fragmented_train_data/hagupit_fragment_train.txt'



#TRAIN1="../dataset4may/SMERP/RetrievedSMERP/level-1/TotalSMERP_T31.tsv"

'''TRAIN1 = '/home/krudra/summarization/codetest/TWEB_REVISION/Training_Data/hydb_RAW_CLASS.txt'
TRAIN2 = '/home/krudra/summarization/codetest/TWEB_REVISION/Training_Data/utkd_RAW_CLASS.txt'
TRAIN3 = '/home/krudra/summarization/codetest/TWEB_REVISION/Training_Data/sandy_hook_RAW_CLASS.txt'
TRAIN4 = '/home/krudra/summarization/codetest/TWEB_REVISION/Training_Data/hagupit_RAW_CLASS.txt' '''

'''TRAIN1 = '/home/krudra/summarization/codetest/TWEB_REVISION/Training_Data/hydb_balance_RAW.txt'
TRAIN2 = '/home/krudra/summarization/codetest/TWEB_REVISION/Training_Data/utkd_balance_RAW.txt'
TRAIN3 = '/home/krudra/summarization/codetest/TWEB_REVISION/Training_Data/sandy_hook_balance_RAW.txt'
TRAIN4 = '/home/krudra/summarization/codetest/TWEB_REVISION/Training_Data/hagupit_balance_RAW.txt' '''


emoticon_string = r"""
    (?:
      [<>]?
      [:;=8]                     # eyes
      [\-o\*\']?                 # optional nose
      [\)\]\(\[dDpP/\:\}\{@\|\\] # mouth      
      |
      [\)\]\(\[dDpP/\:\}\{@\|\\] # mouth
      [\-o\*\']?                 # optional nose
      [:;=8]                     # eyes
      [<>]?
    )"""

TAGGER_PATH = '../../Lexical_resources/ark-tweet-nlp-0.3.2/'

PRONOUN = {}
WHWORD = {}
SLANG = {}
INTENSIFIER = {}
SUBJECTIVE = {}
EVENT = {}
MODAL = {}
RELIGION = {}

def READ_FILES():

	fp = open(PRONOUN_PATH,'r')
        for l in fp:
		PRONOUN[l.strip(' \t\n\r').lower()] = 1
        fp.close()
	
	fp = open(INTENSIFIER_PATH,'r')
        for l in fp:
		INTENSIFIER[l.strip(' \t\n\r').lower()] = 1
        fp.close()
	
	fp = open(WHWORD_PATH,'r')
        for l in fp:
		WHWORD[l.strip(' \t\n\r').lower()] = 1
        fp.close()
	
	fp = open(SLANG_PATH,'r')
        for l in fp:
		SLANG[l.strip(' \t\n\r').lower()] = 1
        fp.close()

	fp = open(EVENT_PATH,'r')
        for l in fp:
		EVENT[l.strip(' \t\n\r').lower()] = 1
        fp.close()

	'''fp = open(NONSIT_PATH,'r')
        for l in fp:
		EVENT[l.strip(' \t\n\r').lower()] = 1
        fp.close() '''
	
	fp = open(MODAL_VERB_PATH,'r')
        for l in fp:
		MODAL[l.strip(' \t\n\r').lower()] = 1
        fp.close()
	
	fp = open(RELIGION_PATH,'r')
        for l in fp:
		RELIGION[l.strip(' \t\n\r').lower()] = 1
        fp.close()

	fp = open(SUBJECTIVE_PATH,'r')
        for l in fp:
                wl = l.split()
                x = wl[0].split('=')[1].strip(' \t\n\r')
                if x=='strongsubj':
                        y = wl[2].split('=')[1].strip(' \t\n\r')
                        SUBJECTIVE[y.lower()] = 1
	fp.close()

############################ This Functions are used #############################################

def emoticons(s):
        return len(re.findall(u'[\U0001f600-\U0001f60f\U0001f617-\U0001f61d\U0001f632\U0001f633\U0001f638-\U0001f63e\U0001f642\U0001f646-\U0001f64f\U0001f612\U0001f613\U0001f615\U0001f616\U0001f61e-\U0001f629\U0001f62c\U0001f62d\U0001f630\U0001f631\U0001f636\U0001f637\U0001f63c\U0001f63f-\U0001f641\U0001f64d]', s))

def smileys(s):
        return len(re.findall(r':\-\)|:[\)\]\}]|:[dDpP]|:3|:c\)|:>|=\]|8\)|=\)|:\^\)|:\-D|[xX8]\-?D|=\-?D|=\-?3|B\^D|:\'\-?\)|>:\[|:\-?\(|:\-?c|:\-?<|:\-?\[|:\{|;\(|:\-\|\||:@|>:\(|:\'\-?\(|D:<?|D[8;=X]|v.v|D\-\':|>:[\/]|:\-[./]|:[\/LS]|=[\/L]|>.<|:\$|>:\-?\)|>;\)|\}:\-?\)|3:\-?\)|\(>_<\)>?|^_?^;|\(#\^.\^#\)|[Oo]_[Oo]|:\-?o',s))

def getNumberOfElongatedWords(s):
    return len(re.findall('([a-zA-Z])\\1{2,}', s))
    
def pronoun(sen):
	
	for x in sen:
		if PRONOUN.__contains__(x)==True:
			return 1
	return 0

def exclamation(s):
	c = len(re.findall(r"[!]", s))
	if c>=1:
		return 1
	return 0

def question(s):
	return len(re.findall(r"[?]", s))

def intensifier(sen):

	count = 0
	for x in sen:
		if INTENSIFIER.__contains__(x)==True:
			count+=1
			#return 1
	if count>0:
		return 1
	return 0

def whword(sen):
	
	for x in sen:
		if WHWORD.__contains__(x)==True:
			return 1
	return 0

def religion(sen):
	
	for x in sen:
		if RELIGION.__contains__(x)==True:
			return 1
	return 0

def slang(sen):
	
	for x in sen:
		if SLANG.__contains__(x)==True:
			return 1
	return 0

def event_phrase(sen):
	
	for x in sen:
		if EVENT.__contains__(x)==True:
			return 1
	return 0

def getHashtagopinion(sen):
	fp = codecs.open(OPINION_HASHTAG_PATH,'r','utf-8')
	temp = set([])
	for l in fp:
		temp.add(l.strip(' \t\n\r').lower())
	fp.close()

	cur_hash = set([])
	for x in sen:
		if x.startswith('#')==True:
			cur_hash.add(x.strip(' \t\n\r').lower())
	size = len(temp.intersection(cur_hash))
	if size>0:
		return 1
	return 0

def numeral(temp):
	c = 0
	for x in temp:
		if x.isdigit()==True:
			c+=1
	return c

def modal(sen):
	for x in sen:
		if MODAL.__contains__(x)==True:
			return 1
	return 0

def subjectivity(sen):
	
        c = 0
        for x in sen:
                if SUBJECTIVE.__contains__(x)==True:
                        c+=1
        tot = len(sen) + 4.0 - 4.0 - 1.0
        num = c + 4.0 - 4.0
	try:
        	s = round(num/tot,4)
	except:
		s = 0
	if c>0:
		return c
	return 0
	#print(s)
	#return s

#HashTagSentimentUnigrams("Oh wrestle", "NRC-Hashtag-Sentiment-Lexicon-v0.1/unigrams-pmilexicon.txt")
#HashTagSentimentUnigrams("Oh no wrestle", "Sentiment140-Lexicon-v0.1/unigrams-pmilexicon.txt")
#print negatedContextCount("this is not for me")
            
if __name__ == '__main__':

	READ_FILES()
	tok = Tokenizer(preserve_case=False)

	fo = open('temp.txt','w')
	fp = open(TRAIN1,'r')
	for l in fp:
	     wl = l.split('\t')
	     fo.write(wl[0].strip(' \t\n\r') + '\n')
	fp.close()
	fo.close()

	command = TAGGER_PATH + '/./runTagger.sh --output-format conll temp.txt > tagfile.txt'
	os.system(command)
	
	fp = open('tagfile.txt','r')
	fs = open(TRAIN1,'r')
	s = ''
	N = 0
	hydb_feature = []
	hydb_label = []
	for l in fp:
		wl = l.split('\t')
		if len(wl)>1:
			word = wl[0].strip(' \t\n\r').lower()
			tag = wl[1].strip(' \t\n\r')
			if tag=='N':
				try:
					w = lmtzr.lemmatize(word)
					word = w
				except Exception as e:
					pass
			elif tag=='V':
				try:
                                	w = Word(word)
                                	x = w.lemmatize("v")
					word = x
				except Exception as e:
                                	pass
			elif tag=='$':
				N+=1
			else:
				pass
			try:
				s = s + word + ' '
			except Exception as e:
				pass
		else:
			unigram = tok.tokenize(s)
			bigram = []
			trigram = []
			if len(unigram)>1:
				for i in range(0,len(unigram)-1,1):
					s = unigram[i] + ' ' + unigram[i+1]
					bigram.append(s)
			if len(unigram)>2:
				for i in range(0,len(unigram)-2,1):
					s = unigram[i] + ' ' + unigram[i+1] + ' ' + unigram[i+2]
					trigram.append(s)
			Ngram = unigram + bigram + trigram
			row = fs.readline().split('\t')
			temp = tok.tokenize(row[0])
			New = []
			if len(temp)>1:
				for i in range(0,len(temp)-1,1):
					s = temp[i] + ' ' + temp[i+1]
					New.append(s)
			if len(temp)>2:
				for i in range(0,len(temp)-2,1):
					s = temp[i] + ' ' + temp[i+1] + ' ' + temp[i+2]
					New.append(s)
			
			Ngram = Ngram + temp + New
			Ngram = set(Ngram)
			Ngram = list(Ngram)
			print(unigram)
			print(temp)
			print(Ngram)
			#sys.exit(0)
			E = exclamation(row[0])
			Q = question(row[0])
			M = modal(Ngram)
			I = intensifier(Ngram)
			W = whword(Ngram)
			EP = event_phrase(Ngram)
			S = subjectivity(temp)
			SG = slang(Ngram)
			P = pronoun(Ngram)
			EL = getNumberOfElongatedWords(row[0])
			RL = religion(Ngram)
			#EM = emoticons(org_tweet[row[1].strip(' \t\n\r')])
			#SM = smileys(row[0].strip(' \t\n\r'))
			#t = [N,E,Q,M,I,W,S,P,EP,SG,EM,SM]
			#t = [N,E,Q,M,I,W,S,P,EP,SG,EL]
			t = [N,E,Q,M,I,W,S,P,EP,SG,RL]
			hydb_feature.append(t)
			hydb_label.append(int(row[1]))
			N = 0
			s = ''
	fp.close()
	fs.close()
	
	IN = []
	CR = []
	PR = []
	RC = []
	FS = []

        hydb_clf = svm.SVC(kernel='rbf',gamma=0.5)
        #hydb_clf = svm.SVC(kernel='rbf')
        #hydb_clf = RandomForestClassifier()
        #hydb_clf = svm.LinearSVC()
        #hydb_clf = LogisticRegression()
        #hydb_clf = BernoulliNB()
        hydb_clf.fit(hydb_feature,hydb_label)
        scores = cross_validation.cross_val_score(hydb_clf,hydb_feature,hydb_label,cv=10)
        print('Hydb: ',scores.mean(),scores.std())
	recall = cross_validation.cross_val_score(hydb_clf, hydb_feature, hydb_label, cv=10, scoring='recall')
        print('Recall', np.mean(recall), recall)
        precision = cross_validation.cross_val_score(hydb_clf, hydb_feature, hydb_label, cv=10, scoring='precision')
        print('Precision', np.mean(precision), precision)
        f1 = cross_validation.cross_val_score(hydb_clf, hydb_feature, hydb_label, cv=10, scoring='f1')
        print('F1', np.mean(f1), f1)
	IN.append(scores.mean())

	fo = open('temp.txt','w')
	fp = open(TRAIN2,'r')
	for l in fp:
		wl = l.split('\t')
		fo.write(wl[0].strip(' \t\n\r') + '\n')
	fp.close()
	fo.close()

	command = TAGGER_PATH + '/./runTagger.sh --output-format conll temp.txt > tagfile.txt'
	os.system(command)
	
	fp = open('tagfile.txt','r')
	fs = open(TRAIN2,'r')
	s = ''
	N = 0
	utkd_feature = []
	utkd_label = []
	for l in fp:
		wl = l.split('\t')
		if len(wl)>1:
			word = wl[0].strip(' \t\n\r').lower()
			tag = wl[1].strip(' \t\n\r')
			if tag=='N':
				try:
					w = lmtzr.lemmatize(word)
					word = w
				except Exception as e:
					pass
			elif tag=='V':
				try:
                                	w = Word(word)
                                	x = w.lemmatize("v")
					word = x
				except Exception as e:
                                	pass
			elif tag=='$':
				N+=1
			else:
				pass
			try:
				s = s + word + ' '
			except Exception as e:
				pass
		else:
			unigram = tok.tokenize(s)
			bigram = []
			trigram = []
			if len(unigram)>1:
				for i in range(0,len(unigram)-1,1):
					s = unigram[i] + ' ' + unigram[i+1]
					bigram.append(s)
			if len(unigram)>2:
				for i in range(0,len(unigram)-2,1):
					s = unigram[i] + ' ' + unigram[i+1] + ' ' + unigram[i+2]
					trigram.append(s)
			Ngram = unigram + bigram + trigram
			row = fs.readline().split('\t')
			temp = tok.tokenize(row[0])
			New = []
			if len(temp)>1:
				for i in range(0,len(temp)-1,1):
					s = temp[i] + ' ' + temp[i+1]
					New.append(s)
			if len(temp)>2:
				for i in range(0,len(temp)-2,1):
					s = temp[i] + ' ' + temp[i+1] + ' ' + temp[i+2]
					New.append(s)
			
			Ngram = Ngram + temp + New
			Ngram = set(Ngram)
			Ngram = list(Ngram)
			E = exclamation(row[0])
			Q = question(row[0])
			M = modal(Ngram)
			I = intensifier(Ngram)
			W = whword(Ngram)
			EP = event_phrase(Ngram)
			S = subjectivity(temp)
			SG = slang(Ngram)
			P = pronoun(Ngram)
			EL = getNumberOfElongatedWords(row[0])
			RL = religion(Ngram)
			#EM = emoticons(org_tweet[row[1].strip(' \t\n\r')])
			#SM = smileys(row[0].strip(' \t\n\r'))
			#t = [N,E,Q,M,I,W,S,P,EP,SG,EM,SM]
			#t = [N,E,Q,M,I,W,S,P,EP,SG,EL]
			t = [N,E,Q,M,I,W,S,P,EP,SG,RL]
			utkd_feature.append(t)
			utkd_label.append(int(row[1]))
			N = 0
			s = ''
	fp.close()
	fs.close()
        
	utkd_clf = svm.SVC(kernel='rbf',gamma=0.5)
        #utkd_clf = svm.SVC(kernel='rbf')
        #utkd_clf = RandomForestClassifier()
        #utkd_clf = svm.LinearSVC()
        #utkd_clf = LogisticRegression()
        #utkd_clf = BernoulliNB()
        utkd_clf.fit(utkd_feature,utkd_label)
        scores = cross_validation.cross_val_score(utkd_clf,utkd_feature,utkd_label,cv=10)
        print('Utkd: ',scores.mean(),scores.std())
	recall = cross_validation.cross_val_score(utkd_clf, utkd_feature, utkd_label, cv=10, scoring='recall')
        print('Recall', np.mean(recall), recall)
        precision = cross_validation.cross_val_score(utkd_clf, utkd_feature, utkd_label, cv=10, scoring='precision')
        print('Precision', np.mean(precision), precision)
        f1 = cross_validation.cross_val_score(utkd_clf, utkd_feature, utkd_label, cv=10, scoring='f1')
        print('F1', np.mean(f1), f1)
	IN.append(scores.mean())
	

	fo = open('temp.txt','w')
	fp = open(TRAIN3,'r')
	for l in fp:
		wl = l.split('\t')
		fo.write(wl[0].strip(' \t\n\r') + '\n')
	fp.close()
	fo.close()

	command = TAGGER_PATH + '/./runTagger.sh --output-format conll temp.txt > tagfile.txt'
	os.system(command)
	
	fp = open('tagfile.txt','r')
	fs = open(TRAIN3,'r')
	s = ''
	N = 0
	sandy_hook_feature = []
	sandy_hook_label = []
	for l in fp:
		wl = l.split('\t')
		if len(wl)>1:
			word = wl[0].strip(' \t\n\r').lower()
			tag = wl[1].strip(' \t\n\r')
			if tag=='N':
				try:
					w = lmtzr.lemmatize(word)
					word = w
				except Exception as e:
					pass
			elif tag=='V':
				try:
                                	w = Word(word)
                                	x = w.lemmatize("v")
					word = x
				except Exception as e:
                                	pass
			elif tag=='$':
				N+=1
			else:
				pass
			try:
				s = s + word + ' '
			except Exception as e:
				pass
		else:
			unigram = tok.tokenize(s)
			bigram = []
			trigram = []
			if len(unigram)>1:
				for i in range(0,len(unigram)-1,1):
					s = unigram[i] + ' ' + unigram[i+1]
					bigram.append(s)
			if len(unigram)>2:
				for i in range(0,len(unigram)-2,1):
					s = unigram[i] + ' ' + unigram[i+1] + ' ' + unigram[i+2]
					trigram.append(s)
			Ngram = unigram + bigram + trigram
			row = fs.readline().split('\t')
			temp = tok.tokenize(row[0])
			New = []
			if len(temp)>1:
				for i in range(0,len(temp)-1,1):
					s = temp[i] + ' ' + temp[i+1]
					New.append(s)
			if len(temp)>2:
				for i in range(0,len(temp)-2,1):
					s = temp[i] + ' ' + temp[i+1] + ' ' + temp[i+2]
					New.append(s)
			
			Ngram = Ngram + temp + New
			Ngram = set(Ngram)
			Ngram = list(Ngram)
			E = exclamation(row[0])
			Q = question(row[0])
			M = modal(Ngram)
			I = intensifier(Ngram)
			W = whword(Ngram)
			EP = event_phrase(Ngram)
			S = subjectivity(temp)
			SG = slang(Ngram)
			P = pronoun(Ngram)
			EL = getNumberOfElongatedWords(row[0])
			RL = religion(Ngram)
			#EM = emoticons(org_tweet[row[1].strip(' \t\n\r')])
			#SM = smileys(row[0].strip(' \t\n\r'))
			#t = [N,E,Q,M,I,W,S,P,EP,SG,EM,SM]
			#t = [N,E,Q,M,I,W,S,P,EP,SG,EL]
			t = [N,E,Q,M,I,W,S,P,EP,SG,RL]
			sandy_hook_feature.append(t)
			sandy_hook_label.append(int(row[1]))
			N = 0
			s = ''
	fp.close()
	fs.close()

        sandy_hook_clf = svm.SVC(kernel='rbf',gamma=0.5)
        #sandy_hook_clf = svm.SVC(kernel='rbf')
        #sandy_hook_clf = RandomForestClassifier()
        #sandy_hook_clf = svm.LinearSVC()
        #sandy_hook_clf = LogisticRegression()
        #sandy_hook_clf = BernoulliNB()
        sandy_hook_clf.fit(sandy_hook_feature,sandy_hook_label)
        scores = cross_validation.cross_val_score(sandy_hook_clf,sandy_hook_feature,sandy_hook_label,cv=10)
        print('SandyHook: ',scores.mean(),scores.std())
	recall = cross_validation.cross_val_score(sandy_hook_clf, sandy_hook_feature, sandy_hook_label, cv=10, scoring='recall')
        print('Recall', np.mean(recall), recall)
        precision = cross_validation.cross_val_score(sandy_hook_clf, sandy_hook_feature, sandy_hook_label, cv=10, scoring='precision')
        print('Precision', np.mean(precision), precision)
        f1 = cross_validation.cross_val_score(sandy_hook_clf, sandy_hook_feature, sandy_hook_label, cv=10, scoring='f1')
        print('F1', np.mean(f1), f1)
	IN.append(scores.mean())
	

	fo = open('temp.txt','w')
	fp = open(TRAIN4,'r')
	for l in fp:
		wl = l.split('\t')
		fo.write(wl[0].strip(' \t\n\r') + '\n')
	fp.close()
	fo.close()

	command = TAGGER_PATH + '/./runTagger.sh --output-format conll temp.txt > tagfile.txt'
	os.system(command)
	
	fp = open('tagfile.txt','r')
	fs = open(TRAIN4,'r')
	s = ''
	N = 0
	hagupit_feature = []
	hagupit_label = []
	for l in fp:
		wl = l.split('\t')
		if len(wl)>1:
			word = wl[0].strip(' \t\n\r').lower()
			tag = wl[1].strip(' \t\n\r')
			if tag=='N':
				try:
					w = lmtzr.lemmatize(word)
					word = w
				except Exception as e:
					pass
			elif tag=='V':
				try:
                                	w = Word(word)
                                	x = w.lemmatize("v")
					word = x
				except Exception as e:
                                	pass
			elif tag=='$':
				N+=1
			else:
				pass
			try:
				s = s + word + ' '
			except Exception as e:
				pass
		else:
			unigram = tok.tokenize(s)
			bigram = []
			trigram = []
			if len(unigram)>1:
				for i in range(0,len(unigram)-1,1):
					s = unigram[i] + ' ' + unigram[i+1]
					bigram.append(s)
			if len(unigram)>2:
				for i in range(0,len(unigram)-2,1):
					s = unigram[i] + ' ' + unigram[i+1] + ' ' + unigram[i+2]
					trigram.append(s)
			Ngram = unigram + bigram + trigram
			row = fs.readline().split('\t')
			temp = tok.tokenize(row[0])
			New = []
			if len(temp)>1:
				for i in range(0,len(temp)-1,1):
					s = temp[i] + ' ' + temp[i+1]
					New.append(s)
			if len(temp)>2:
				for i in range(0,len(temp)-2,1):
					s = temp[i] + ' ' + temp[i+1] + ' ' + temp[i+2]
					New.append(s)
			
			Ngram = Ngram + temp + New
			Ngram = set(Ngram)
			Ngram = list(Ngram)
			E = exclamation(row[0])
			Q = question(row[0])
			M = modal(Ngram)
			I = intensifier(Ngram)
			W = whword(Ngram)
			EP = event_phrase(Ngram)
			S = subjectivity(temp)
			SG = slang(Ngram)
			P = pronoun(Ngram)
			EL = getNumberOfElongatedWords(row[0])
			RL = religion(Ngram)
			#EM = emoticons(org_tweet[row[1].strip(' \t\n\r')])
			#SM = smileys(row[0].strip(' \t\n\r'))
			#t = [N,E,Q,M,I,W,S,P,EP,SG,EM,SM]
			#t = [N,E,Q,M,I,W,S,P,EP,SG,EL]
			t = [N,E,Q,M,I,W,S,P,EP,SG,RL]
			hagupit_feature.append(t)
			hagupit_label.append(int(row[1]))
			N = 0
			s = ''
	fp.close()
	fs.close()

        hagupit_clf = svm.SVC(kernel='rbf',gamma=0.5)
        #hagupit_clf = svm.SVC(kernel='rbf')
        #hagupit_clf = RandomForestClassifier()
        #hagupit_clf = svm.LinearSVC()
        #hagupit_clf = LogisticRegression()
        #hagupit_clf = BernoulliNB()
        hagupit_clf.fit(hagupit_feature,hagupit_label)
        scores = cross_validation.cross_val_score(hagupit_clf,hagupit_feature,hagupit_label,cv=10)
        print('Hagupit: ',scores.mean(),scores.std())
	recall = cross_validation.cross_val_score(hagupit_clf, hagupit_feature, hagupit_label, cv=10, scoring='recall')
        print('Recall', np.mean(recall), recall)
        precision = cross_validation.cross_val_score(hagupit_clf, hagupit_feature, hagupit_label, cv=10, scoring='precision')
        print('Precision', np.mean(precision), precision)
        f1 = cross_validation.cross_val_score(hagupit_clf, hagupit_feature, hagupit_label, cv=10, scoring='f1')
        print('F1', np.mean(f1), f1)
	IN.append(scores.mean())
			
        
	print('Train Hydb')
        print('Utkd: ',hydb_clf.score(utkd_feature,utkd_label))
        print('Sandy_Hook: ',hydb_clf.score(sandy_hook_feature,sandy_hook_label))
        print('Hagupit: ',hydb_clf.score(hagupit_feature,hagupit_label))
	CR.append(hydb_clf.score(utkd_feature,utkd_label))
	CR.append(hydb_clf.score(sandy_hook_feature,sandy_hook_label))
	CR.append(hydb_clf.score(hagupit_feature,hagupit_label))

        print('Train Utkd')
        print('Hydb: ',utkd_clf.score(hydb_feature,hydb_label))
        print('Sandy_Hook: ',utkd_clf.score(sandy_hook_feature,sandy_hook_label))
        print('Hagupit: ',utkd_clf.score(hagupit_feature,hagupit_label))
	CR.append(utkd_clf.score(hydb_feature,hydb_label))
	CR.append(utkd_clf.score(sandy_hook_feature,sandy_hook_label))
	CR.append(utkd_clf.score(hagupit_feature,hagupit_label))

        print('Train Sandy_Hook')
        print('Hydb: ',sandy_hook_clf.score(hydb_feature,hydb_label))
        print('Utkd: ',sandy_hook_clf.score(utkd_feature,utkd_label))
        print('Hagupit: ',sandy_hook_clf.score(hagupit_feature,hagupit_label))
	CR.append(sandy_hook_clf.score(hydb_feature,hydb_label))
	CR.append(sandy_hook_clf.score(utkd_feature,utkd_label))
	CR.append(sandy_hook_clf.score(hagupit_feature,hagupit_label))

        print('Train Hagupit')
        print('Hydb: ',hagupit_clf.score(hydb_feature,hydb_label))
        print('Utkd: ',hagupit_clf.score(utkd_feature,utkd_label))
        print('Sandy_Hook: ',hagupit_clf.score(sandy_hook_feature,sandy_hook_label))
	CR.append(hagupit_clf.score(hydb_feature,hydb_label))
	CR.append(hagupit_clf.score(utkd_feature,utkd_label))
	CR.append(hagupit_clf.score(sandy_hook_feature,sandy_hook_label))
	print('\n\n')
	
	########################################## Precision Recall F-score ###################################################
	utkd_predicted_label = hydb_clf.predict(utkd_feature)
	print('Hydb -> utkd | sandy_hook | hagupit')
	print('PRECISION: ',metrics.precision_score(utkd_label,utkd_predicted_label))
        print('RECALL: ',metrics.recall_score(utkd_label,utkd_predicted_label))
        print('F1_SCORE: ',metrics.f1_score(utkd_label,utkd_predicted_label))
	PR.append(metrics.precision_score(utkd_label,utkd_predicted_label))
	RC.append(metrics.recall_score(utkd_label,utkd_predicted_label))
	FS.append(metrics.f1_score(utkd_label,utkd_predicted_label))
	
	sandy_hook_predicted_label = hydb_clf.predict(sandy_hook_feature)
	print('PRECISION: ',metrics.precision_score(sandy_hook_label,sandy_hook_predicted_label))
        print('RECALL: ',metrics.recall_score(sandy_hook_label,sandy_hook_predicted_label))
        print('F1_SCORE: ',metrics.f1_score(sandy_hook_label,sandy_hook_predicted_label))
	PR.append(metrics.precision_score(sandy_hook_label,sandy_hook_predicted_label))
        RC.append(metrics.recall_score(sandy_hook_label,sandy_hook_predicted_label))
        FS.append(metrics.f1_score(sandy_hook_label,sandy_hook_predicted_label))
	
	hagupit_predicted_label = hydb_clf.predict(hagupit_feature)
	print('PRECISION: ',metrics.precision_score(hagupit_label,hagupit_predicted_label))
        print('RECALL: ',metrics.recall_score(hagupit_label,hagupit_predicted_label))
        print('F1_SCORE: ',metrics.f1_score(hagupit_label,hagupit_predicted_label))
	PR.append(metrics.precision_score(hagupit_label,hagupit_predicted_label))
        RC.append(metrics.recall_score(hagupit_label,hagupit_predicted_label))
        FS.append(metrics.f1_score(hagupit_label,hagupit_predicted_label))

	print('\n\n')
	
	#########################################################################################################################
	hydb_predicted_label = utkd_clf.predict(hydb_feature)
	print('Utkd -> hydb | sandy_hook | hagupit')
	print('PRECISION: ',metrics.precision_score(hydb_label,hydb_predicted_label))
        print('RECALL: ',metrics.recall_score(hydb_label,hydb_predicted_label))
        print('F1_SCORE: ',metrics.f1_score(hydb_label,hydb_predicted_label))
	PR.append(metrics.precision_score(hydb_label,hydb_predicted_label))
        RC.append(metrics.recall_score(hydb_label,hydb_predicted_label))
        FS.append(metrics.f1_score(hydb_label,hydb_predicted_label))
	
	sandy_hook_predicted_label = utkd_clf.predict(sandy_hook_feature)
	print('PRECISION: ',metrics.precision_score(sandy_hook_label,sandy_hook_predicted_label))
        print('RECALL: ',metrics.recall_score(sandy_hook_label,sandy_hook_predicted_label))
        print('F1_SCORE: ',metrics.f1_score(sandy_hook_label,sandy_hook_predicted_label))
	PR.append(metrics.precision_score(sandy_hook_label,sandy_hook_predicted_label))
        RC.append(metrics.recall_score(sandy_hook_label,sandy_hook_predicted_label))
        FS.append(metrics.f1_score(sandy_hook_label,sandy_hook_predicted_label))
	
	hagupit_predicted_label = utkd_clf.predict(hagupit_feature)
	print('PRECISION: ',metrics.precision_score(hagupit_label,hagupit_predicted_label))
        print('RECALL: ',metrics.recall_score(hagupit_label,hagupit_predicted_label))
        print('F1_SCORE: ',metrics.f1_score(hagupit_label,hagupit_predicted_label))
	PR.append(metrics.precision_score(hagupit_label,hagupit_predicted_label))
        RC.append(metrics.recall_score(hagupit_label,hagupit_predicted_label))
        FS.append(metrics.f1_score(hagupit_label,hagupit_predicted_label))
	print('\n\n')

	###########################################################################################################################
	hydb_predicted_label = sandy_hook_clf.predict(hydb_feature)
	print('Sandy_hook -> hydb | utkd | hagupit')
	print('PRECISION: ',metrics.precision_score(hydb_label,hydb_predicted_label))
        print('RECALL: ',metrics.recall_score(hydb_label,hydb_predicted_label))
        print('F1_SCORE: ',metrics.f1_score(hydb_label,hydb_predicted_label))
	PR.append(metrics.precision_score(hydb_label,hydb_predicted_label))
        RC.append(metrics.recall_score(hydb_label,hydb_predicted_label))
        FS.append(metrics.f1_score(hydb_label,hydb_predicted_label))
	
	utkd_predicted_label = sandy_hook_clf.predict(utkd_feature)
	print('PRECISION: ',metrics.precision_score(utkd_label,utkd_predicted_label))
        print('RECALL: ',metrics.recall_score(utkd_label,utkd_predicted_label))
        print('F1_SCORE: ',metrics.f1_score(utkd_label,utkd_predicted_label))
	PR.append(metrics.precision_score(utkd_label,utkd_predicted_label))
	RC.append(metrics.recall_score(utkd_label,utkd_predicted_label))
	FS.append(metrics.f1_score(utkd_label,utkd_predicted_label))
	
	hagupit_predicted_label = sandy_hook_clf.predict(hagupit_feature)
	print('PRECISION: ',metrics.precision_score(hagupit_label,hagupit_predicted_label))
        print('RECALL: ',metrics.recall_score(hagupit_label,hagupit_predicted_label))
        print('F1_SCORE: ',metrics.f1_score(hagupit_label,hagupit_predicted_label))
	PR.append(metrics.precision_score(hagupit_label,hagupit_predicted_label))
        RC.append(metrics.recall_score(hagupit_label,hagupit_predicted_label))
        FS.append(metrics.f1_score(hagupit_label,hagupit_predicted_label))
	print('\n\n')

	############################################################################################################################
	
	print('Hagupit -> hydb | utkd | sandy_hook')
	hydb_predicted_label = hagupit_clf.predict(hydb_feature)
	print('PRECISION: ',metrics.precision_score(hydb_label,hydb_predicted_label))
        print('RECALL: ',metrics.recall_score(hydb_label,hydb_predicted_label))
        print('F1_SCORE: ',metrics.f1_score(hydb_label,hydb_predicted_label))
	PR.append(metrics.precision_score(hydb_label,hydb_predicted_label))
        RC.append(metrics.recall_score(hydb_label,hydb_predicted_label))
        FS.append(metrics.f1_score(hydb_label,hydb_predicted_label))
	
	utkd_predicted_label = hagupit_clf.predict(utkd_feature)
	print('PRECISION: ',metrics.precision_score(utkd_label,utkd_predicted_label))
        print('RECALL: ',metrics.recall_score(utkd_label,utkd_predicted_label))
        print('F1_SCORE: ',metrics.f1_score(utkd_label,utkd_predicted_label))
	PR.append(metrics.precision_score(utkd_label,utkd_predicted_label))
	RC.append(metrics.recall_score(utkd_label,utkd_predicted_label))
	FS.append(metrics.f1_score(utkd_label,utkd_predicted_label))
	
	sandy_hook_predicted_label = hagupit_clf.predict(sandy_hook_feature)
	print('PRECISION: ',metrics.precision_score(sandy_hook_label,sandy_hook_predicted_label))
        print('RECALL: ',metrics.recall_score(sandy_hook_label,sandy_hook_predicted_label))
        print('F1_SCORE: ',metrics.f1_score(sandy_hook_label,sandy_hook_predicted_label))
	PR.append(metrics.precision_score(sandy_hook_label,sandy_hook_predicted_label))
        RC.append(metrics.recall_score(sandy_hook_label,sandy_hook_predicted_label))
        FS.append(metrics.f1_score(sandy_hook_label,sandy_hook_predicted_label))
	
	print(len(IN),len(CR),len(PR),len(RC),len(FS))
        print('Average Indomain Accuracy: ',np.mean(IN))
        print('Average Cross-domain Accuracy: ',np.mean(CR))
        print('Average and std Precision: ',np.mean(PR),np.std(PR))
        print('Average and std Recall: ',np.mean(RC),np.std(RC))
        print('Average and std F-score: ',np.mean(FS),np.std(FS))
# Out:
# ['be', 'it', 'cong', 'supporter', 'right', 'wing', 'hindutva', 'extremist', 'behind', 'bomb', 'blast', 'in', 'the', 'indian', 'city', 'of', 'hyderabad', '.']
# ['is', 'it', 'cong', 'supporter', 'right', 'wing', 'hindutva', 'extremists', 'behind', 'bomb', 'blasts', 'in', 'the', 'indian', 'city', 'of', 'hyderabad', '.']
# ['extremist behind bomb', 'hyderabad', 'bomb blasts', 'right', 'bomb', 'wing hindutva', 'wing hindutva extremist', 'be it', 'is', 'cong', 'it', 'it cong supporter', 'behind bomb blasts', 'extremist', 'wing hindutva extremists', 'the indian', 'cong supporter', 'bomb blast in', 'in', 'indian city of', 'city of hyderabad', 'hindutva', 'supporter', 'blast in the', 'extremists behind bomb', 'city', 'of hyderabad .', 'cong supporter right', 'in the indian', 'is it', '.', 'behind', 'indian', 'blasts in', 'right wing', 'indian city', 'hindutva extremist', 'be', 'blasts in the', 'be it cong', 'right wing hindutva', 'hyderabad .', 'hindutva extremist behind', 'blasts', 'behind bomb', 'in the', 'blast', 'extremists behind', 'supporter right wing', 'is it cong', 'hindutva extremists', 'supporter right', 'city of', 'bomb blasts in', 'of', 'behind bomb blast', 'the indian city', 'extremist behind', 'hindutva extremists behind', 'extremists', 'blast in', 'bomb blast', 'it cong', 'the', 'of hyderabad', 'wing']
# ['lashkar', 'announce', 'unconditional', 'surrender', 'after', 'manmohan', 'singh', 'strongly', 'condemn', 'the', 'hyderabadblasts', '.']
# ['lashkar', 'announces', 'unconditional', 'surrender', 'after', 'manmohan', 'singh', 'strongly', 'condemns', 'the', 'hyderabadblasts', '.']
# ['yasin', 'bhatkal', 'be', 'out', 'on', 'bail', ',', 'he', 'could', 'be', 'behind', 'hyderabad', 'blast', '.']
# ['yasin', 'bhatkal', 'is', 'out', 'on', 'bail', ',', 'he', 'could', 'be', 'behind', 'hyderabad', 'blasts', '.']
# ['hyderabad', 'behind hyderabad blast', 'is out on', 'blast .', 'is', ', he could', 'on bail', 'could be behind', 'bail ,', 'on bail ,', 'yasin bhatkal be', 'bail', 'out', 'hyderabad blasts', 'yasin bhatkal', 'bhatkal is out', 'is out', 'be out', ',', '.', 'out on', 'behind', 'yasin bhatkal is', 'out on bail', 'be out on', 'bhatkal', 'behind hyderabad blasts', 'be', 'could be', 'on', 'hyderabad blasts .', 'blasts .', 'he could', 'he could be', 'hyderabad blast .', 'bail , he', 'blast', 'bhatkal be', 'he', 'yasin', 'be behind', 'could', ', he', 'blasts', 'bhatkal be out', 'behind hyderabad', 'bhatkal is', 'hyderabad blast', 'be behind hyderabad']
# ['blast', 'in', 'hyderabad', 'kill', 'at', 'least', '11', ',', 'injure', 'dozen', '.']
# ['blasts', 'in', 'hyderabad', 'kill', 'at', 'least', '11', ',', 'injure', 'dozens', '.']
# ['hyderabad', 'hyderabad kill', 'injure dozen', ', injure dozen', 'kill', 'at', 'in', 'kill at least', 'dozen', 'injure', 'injure dozens', ',', 'least', '.', ', injure dozens', 'blasts in', 'blasts in hyderabad', 'in hyderabad', '11 ,', 'dozens', 'injure dozen .', 'kill at', ', injure', 'least 11', 'blast in hyderabad', 'dozens .', 'injure dozens .', '11 , injure', 'blast', '11', 'dozen .', 'at least', 'at least 11', 'blasts', 'blast in', 'least 11 ,', 'in hyderabad kill', 'hyderabad kill at']
# ['hyderabad', 'blast', ',', 'terror', 'hunt', 'spread', 'to', 'bihar', ',', 'up', ',', 'jharkhand', '.']
# ['hyderabad', 'blast', ',', 'terror', 'hunt', 'spreads', 'to', 'bihar', ',', 'up', ',', 'jharkhand', '.']
# ['hyderabad', ', terror', 'spreads', 'blast ,', ', jharkhand .', 'hunt spreads', 'jharkhand .', 'terror hunt', 'spreads to', 'hunt spreads to', 'to bihar ,', 'spread', 'bihar ,', 'hunt spread to', 'spreads to bihar', 'to bihar', ',', '.', 'terror hunt spread', 'to', 'hunt spread', 'terror', 'bihar', 'jharkhand', ', terror hunt', 'terror hunt spreads', ', jharkhand', 'bihar , up', ', up ,', 'blast', 'blast , terror', 'hunt', 'up', 'up ,', 'spread to bihar', 'hyderabad blast', 'hyderabad blast ,', 'up , jharkhand', 'spread to', ', up']
# ['hyderabad', 'blast', ',', 'multiple', 'death', ',', 'india', 'be', 'on', 'high', 'alert', 'after', 'three', 'explosion', 'in', 'the', 'southern', 'city', 'of', 'hyde', '.']
# ['hyderabad', 'blast', ',', 'multiple', 'deaths', ',', 'india', 'is', 'on', 'high', 'alert', 'after', 'three', 'explosions', 'in', 'the', 'southern', 'city', 'of', 'hyde', '.']
# ['hyderabad', 'multiple deaths', 'blast ,', 'three explosions', 'deaths', 'after three explosions', 'on high', 'be on', 'india', 'deaths , india', 'three', 'high', ', india', 'hyde', 'in', 'hyde .', 'explosion', 'after three explosion', 'city of hyde', 'in the southern', 'is on high', 'city', 'death', 'multiple death', 'of hyde', 'multiple deaths ,', 'the southern city', ', multiple', 'high alert', ',', '.', 'india is on', 'india is', 'high alert after', 'be on high', 'blast , multiple', 'southern city of', 'is', 'three explosion in', 'be', 'death , india', 'explosion in the', 'multiple', 'after', 'southern', 'deaths ,', 'alert', ', multiple deaths', 'explosions in the', 'india be', 'explosion in', 'in the', 'blast', 'death ,', 'explosions', ', india is', 'on', 'hyderabad blast ,', 'multiple death ,', 'three explosion', 'of', 'city of', 'explosions in', ', india be', 'of hyde .', 'after three', 'three explosions in', 'the southern', 'is on', ', multiple death', 'alert after three', 'southern city', 'hyderabad blast', 'the', 'alert after', 'india be on', 'on high alert']
# ["wasn't", 'owaisi', 'hint', '2wards', 'this', 'toll', 'now', '14', 'dead', ',', '119', 'injured', 'and', '6', 'critical', '.']
# ["wasn't", 'owaisi', 'hinting', '2wards', 'this', 'toll', 'now', '14', 'dead', ',', '119', 'injured', 'and', '6', 'critical', '.']
# ['and', '2wards this', 'injured and 6', "wasn't owaisi hinting", 'dead', 'dead ,', 'injured and', 'this toll now', 'and 6 critical', 'critical .', '2wards this toll', 'hinting 2wards this', '119 injured', '119', 'toll now 14', 'hint', 'now 14', ',', 'hint 2wards this', '.', '119 injured and', 'critical', '6', '6 critical', 'owaisi hinting', 'injured', 'hint 2wards', 'and 6', 'toll', 'hinting 2wards', "wasn't owaisi", 'owaisi', 'owaisi hint', ', 119', 'owaisi hinting 2wards', 'now', '2wards', 'toll now', 'now 14 dead', '6 critical .', '14', "wasn't", 'hinting', ', 119 injured', 'this toll', 'this', '14 dead ,', 'dead , 119', "wasn't owaisi hint", '14 dead', 'owaisi hint 2wards']
# ['dilsukhnagar', 'limp', 'back', 'to', 'normalcy', ',', 'traffic', 'return', 'to', 'normal', 'and', 'commercial', '.']
# ['dilsukhnagar', 'limping', 'back', 'to', 'normalcy', ',', 'traffic', 'returned', 'to', 'normal', 'and', 'commercial', '.']
# ['and', 'to normal and', 'traffic return to', 'dilsukhnagar limp', 'dilsukhnagar limping back', 'normal and commercial', 'limp', 'back', 'returned to', 'limping', 'back to normalcy', 'returned to normal', 'dilsukhnagar limp back', 'traffic return', ', traffic', 'limping back to', 'traffic returned', 'normalcy ,', 'limping back', ',', ', traffic returned', '.', 'to', 'return to', 'to normal', 'limp back', 'to normalcy', 'to normalcy ,', 'return', 'returned', 'normal', 'commercial', 'limp back to', 'normal and', 'normalcy , traffic', 'normalcy', 'traffic', 'and commercial .', ', traffic return', 'traffic returned to', 'dilsukhnagar', 'back to', 'commercial .', 'return to normal', 'dilsukhnagar limping', 'and commercial']
# ['hyderabad', ', hyderabad blast', 'to those', 'blast ,', 'compensation to', ',', 'disabled', 'analysis', '6 lakh compensation', 'permanently disabled', 'disabled daily news', 'news &', 'lakh', ', rs 6', 'lakh compensation', 'rs', '& analysis ,', 'daily news', 'blast , rs', ', rs', '.', 'to', 'permanently', 'permanently disabled daily', '6', 'compensation to those', ', .', 'those permanently disabled', 'to those permanently', '6 lakh', 'those permanently', 'news & analysis', 'lakh compensation to', 'analysis , hyderabad', ', hyderabad', 'news', 'blast', 'rs 6 lakh', 'disabled daily', 'those', 'rs 6', 'analysis ,', 'daily news &', '&', 'daily', 'compensation', '& analysis', 'hyderabad blast', 'hyderabad blast ,', 'blast , .']
# ['investigation', 'picks-up', 'in', 'twin', 'hyderabad', 'blast', 'case', '.']
# ['investigation', 'picks-up', 'in', 'twin', 'hyderabad', 'blast', 'case', '.']
# ['case', 'hyderabad', 'case .', 'investigation picks-up', 'blast case', 'picks-up in', 'in twin', '.', 'in twin hyderabad', 'twin', 'investigation', 'picks-up in twin', 'investigation picks-up in', 'in', 'twin hyderabad blast', 'hyderabad blast', 'hyderabad blast case', 'blast', 'picks-up', 'blast case .', 'twin hyderabad']
# ['government', 'have', 'warn', 'of', 'bomb', 'that', 'kill', '16', 'in', 'hyderabad', '.']
# ['government', 'had', 'warned', 'of', 'bombs', 'that', 'killed', '16', 'in', 'hyderabad', '.']
# ['hyderabad', 'had warned', 'bomb', 'of bombs that', 'government had warned', 'warned of', 'hyderabad .', 'that kill', 'have warn of', 'kill', 'that killed 16', 'have', 'in', 'bombs that', 'had warned of', 'in hyderabad .', 'that killed', '16 in', 'government had', 'government have warn', 'had', '16 in hyderabad', '.', 'of bombs', 'of bomb that', 'bomb that kill', 'in hyderabad', 'have warn', 'bombs', 'that', 'government', 'bombs that killed', 'warn', 'kill 16 in', 'killed 16', 'killed 16 in', 'killed', 'of bomb', 'warn of', '16', 'of', 'bomb that', 'warned of bombs', 'warn of bomb', 'kill 16', 'government have', 'warned', 'that kill 16']
# ['india', 'police', 'say', 'be', 'warn', 'about', 'hyderabad', 'bomb', 'threat', '.']
# ['india', 'police', 'say', 'were', 'warned', 'about', 'hyderabad', 'bomb', 'threat', '.']
# ['warned about', 'hyderabad', 'bomb', 'india', 'say', 'bomb threat .', 'bomb threat', 'hyderabad bomb threat', 'be warn', 'police', 'india police say', 'police say were', 'warned about hyderabad', '.', 'say be', 'police say', 'police say be', 'about hyderabad', 'say be warn', 'be', 'threat', 'about hyderabad bomb', 'warn about', 'warn', 'be warn about', 'hyderabad bomb', 'india police', 'were warned about', 'warn about hyderabad', 'about', 'say were warned', 'warned', 'say were', 'were warned', 'threat .', 'were']
# ['hyderabad', 'blast', ',', 'i', 'can', 'see', 'venkatadri', 'theater', 'and', 'dilsukhnagar', 'bus', 'stop', 'from', 'my', 'apartment', '.']
# ['hyderabad', 'blast', ',', 'i', 'can', 'see', 'venkatadri', 'theater', 'and', 'dilsukhnagar', 'bus', 'stop', 'from', 'my', 'apartments', '.']
# ['police', 'suspect', 'one', 'of', 'the', 'bomb', 'may', 'have', 'be', 'keep', 'on', 'a', 'motorcycle', 'the', 'other', 'in', 'a', 'tiffin', 'box', '.']
# ['police', 'suspect', 'one', 'of', 'the', 'bombs', 'may', 'have', 'been', 'kept', 'on', 'a', 'motorcycle', 'the', 'other', 'in', 'a', 'tiffin', 'box', '.']
# ['have be', 'bomb', 'suspect one', 'one of', 'box', 'one', 'motorcycle', 'have', 'in', 'the bomb may', 'of the bomb', 'keep', 'have be keep', 'bombs may', 'the other', 'police', 'a tiffin box', 'the bombs may', 'bombs may have', 'the bombs', 'been', '.', 'box .', 'motorcycle the', 'motorcycle the other', 'other', 'suspect', 'been kept on', 'in a', 'be keep', 'may have been', 'a tiffin', 'a motorcycle', 'have been kept', 'be', 'tiffin', 'been kept', 'kept on', 'be keep on', 'may', 'of the bombs', 'bomb may have', 'in a tiffin', 'have been', 'keep on', 'keep on a', 'police suspect one', 'suspect one of', 'a motorcycle the', 'of the', 'one of the', 'tiffin box .', 'a', 'on', 'bomb may', 'kept', 'tiffin box', 'on a motorcycle', 'of', 'other in', 'police suspect', 'other in a', 'kept on a', 'bombs', 'the bomb', 'may have be', 'the', 'the other in', 'may have', 'on a']
# ['what', 'picture', 'picture', 'of', 'dead', 'body', ',', 'their', 'body', 'tear', 'apart', 'send', 'us', 'your', 'picture', 'from', 'hyderabad', 'blast', 'at', '.']
# ['what', 'pictures', 'pictures', 'of', 'dead', 'bodies', ',', 'their', 'bodies', 'torn', 'apart', 'send', 'us', 'your', 'pictures', 'from', 'hyderabad', 'blasts', 'at', '.']
# ['dead bodies ,', ', their', ', their bodies', 'dead body ,', 'torn', ',', 'send', 'your picture from', 'bodies , their', 'blast at', 'what pictures', 'tear apart send', 'pictures from', 'blast', 'apart', 'apart send', 'your pictures from', 'tear', 'hyderabad blasts at', 'what picture', 'their body tear', 'picture picture of', 'blasts at .', 'dead body', 'torn apart send', 'apart send us', 'us your pictures', 'dead', 'body , their', 'us', 'their body', 'pictures pictures of', 'what', 'pictures', 'pictures from hyderabad', 'body', 'what pictures pictures', 'your pictures', 'hyderabad blast at', 'send us', 'tear apart', 'of dead body', 'of', 'blasts', 'bodies torn apart', 'bodies torn', 'hyderabad', 'at .', 'body tear', 'of dead bodies', 'body tear apart', 'your', 'pictures of', 'from hyderabad blast', 'from', 'blast at .', '.', 'of dead', 'their', 'dead bodies', 'send us your', 'from hyderabad blasts', 'picture from hyderabad', 'pictures pictures', 'their bodies', 'us your picture', 'body ,', 'hyderabad blast', 'picture from', 'bodies ,', 'hyderabad blasts', 'picture of', 'picture picture', 'pictures of dead', 'at', 'what picture picture', 'from hyderabad', 'your picture', 'us your', 'picture', 'picture of dead', 'their bodies torn', ', their body', 'torn apart', 'blasts at', 'bodies']
al', 'condemn bomb', 'pm condemn bomb', 'condemns bomb blasts', 'hyderabad appeal for', 'hyderabad appeals', 'blasts in', 'pm condemns bomb', ', hyderabad appeals', 'hyderabad appeal', ', hyderabad', 'hyderabad appeals for', 'blast', 'for calm .', 'dilsukh nagar', 'appeals for', 'pm condemn', 'blasts in dilsukh', 'appeals for calm', 'bomb blasts in', 'blasts', 'blast in', 'bomb blast', 'in dilsukh', 'in dilsukh nagar', 'appeal for calm']
# ['ten', 'kill', ',', 'several', 'injured', ',', 'high', 'alert', 'in', 'major', 'city', 'across', 'india', '.']
# ['ten', 'killed', ',', 'several', 'injured', ',', 'high', 'alert', 'in', 'major', 'cities', 'across', 'india', '.']
# ['major', ', high alert', 'ten', 'city across india', 'india', 'in major city', 'city across', 'high', 'ten kill', 'kill', 'in', 'india .', 'kill ,', 'several injured', 'major city', 'alert in', 'city', 'in major cities', 'killed , several', 'high alert', ',', '.', 'ten killed', 'injured , high', 'across india .', 'in major', 'killed ,', 'ten killed ,', 'several', 'across', 'killed', 'injured', ', several', 'across india', 'several injured ,', 'alert', 'major cities across', 'kill , several', 'cities', 'major city across', 'major cities', 'alert in major', 'cities across india', ', several injured', 'cities across', 'ten kill ,', ', high', 'injured ,', 'high alert in']
# ['if', 'there', 'be', 'any', 'need', 'for', 'blood', ',', 'please', 'contact', 'ln', 'gupta', ',', 'dc', 'blood', 'donation', '.']
# ['if', 'there', 'is', 'any', 'need', 'for', 'blood', ',', 'please', 'contact', 'ln', 'gupta', ',', 'dc', 'blood', 'donation', '.']
# ['blood donation', ', dc blood', 'if there be', 'gupta', 'contact ln', 'for blood ,', 'blood , please', 'need', 'blood donation .', 'dc blood', 'any', 'if', ', please contact', 'there is any', 'for', 'ln', 'there', 'please', ',', 'donation .', '.', 'please contact', 'is any need', 'be any need', 'there be', 'any need for', 'ln gupta ,', 'gupta ,', 'need for blood', 'be', 'there be any', 'if there is', 'dc', ', please', 'donation', 'blood', 'blood ,', 'is', 'be any', 'is any', 'dc blood donation', 'gupta , dc', 'if there', 'ln gupta', 'for blood', 'contact ln gupta', 'any need', 'contact', 'please contact ln', 'need for', 'there is', ', dc']
# ['hyderabad', 'blast', 'dead', 'body', ',', '.']
# ['hyderabad', 'blast', 'dead', 'bodies', ',', '.']
# ['body', 'hyderabad', 'dead body', 'blast dead bodies', ', .', 'hyderabad blast dead', 'body , .', ',', 'dead', '.', 'bodies , .', 'dead bodies ,', 'body ,', 'bodies', 'dead bodies', 'hyderabad blast', 'blast', 'bodies ,', 'dead body ,', 'blast dead', 'blast dead body']
# ['video', 'hyderabad', ',', 'mecca', 'masjid', 'blast', 'survivor', 'among', 'those', 'injure', '.']
# ['video', 'hyderabad', ',', 'mecca', 'masjid', 'blast', 'survivor', 'among', 'those', 'injured', '.']
# ['blast survivor among', 'hyderabad', 'among', 'survivor among those', 'hyderabad ,', 'video', 'video hyderabad ,', 'mecca masjid', 'mecca', ', mecca masjid', 'masjid blast survivor', 'injure', ',', '.', 'mecca masjid blast', 'video hyderabad', 'those injure .', 'among those injure', 'blast survivor', 'among those injured', 'injured', 'masjid blast', 'survivor among', 'masjid', ', mecca', 'blast', 'among those', 'those', 'those injure', 'survivor', 'hyderabad , mecca', 'injure .', 'those injured .', 'injured .', 'those injured']
# ['16', 'kill', 'in', 'hyderabad', 'blast', '.']
# ['16', 'killed', 'in', 'hyderabad', 'blast', '.']
# ['killed in', 'hyderabad', 'kill in', 'killed in hyderabad', '16', 'in hyderabad blast', 'hyderabad blast', '16 kill in', 'blast .', '.', '16 killed', 'kill in hyderabad', 'hyderabad blast .', 'kill', '16 killed in', 'in', 'in hyderabad', 'blast', '16 kill', 'killed']
# ['whom', 'to', 'blame', ',', 'may', 'god', 'help', 'those', 'family', '.']
# ['whom', 'to', 'blame', ',', 'may', 'god', 'help', 'those', 'families', '.']
# ['help', 'family', 'those family', ', may', 'blame , may', 'help those', 'god help', 'god', 'may god', 'whom to blame', ',', '.', ', may god', 'to', 'blame ,', 'help those family', 'god help those', 'those families', 'help those families', 'families', 'family .', 'may', 'those family .', 'to blame', 'blame', 'may god help', 'those', 'families .', 'those families .', 'whom', 'to blame ,', 'whom to']
# ['i', 'send', 'my', 'condolence', 'to', 'victim', 'of', 'hyderabad', 'blast', 'victim', ',', 'pm', '.']
# ['i', 'send', 'my', 'condolences', 'to', 'victims', 'of', 'hyderabad', 'blast', 'victims', ',', 'pm', '.']
# ['blast victim ,', 'hyderabad', 'send my condolence', ', pm .', 'victims of hyderabad', 'my condolences to', 'victim of hyderabad', 'victim ,', 'condolence to victim', 'victim', 'my condolence', 'of hyderabad blast', 'victims ,', 'blast victims', 'blast', 'to victim of', ',', 'send', '.', 'to', 'victim of', 'my condolences', 'condolences to victims', 'condolence', 'victims , pm', ', pm', 'blast victim', 'of hyderabad', 'victims', 'my condolence to', 'to victims of', 'hyderabad blast victim', 'to victims', 'i send my', 'condolence to', 'blast victims ,', 'i send', 'to victim', 'hyderabad blast victims', 'send my', 'send my condolences', 'victims of', 'victim , pm', 'i', 'of', 'condolences to', 'pm .', 'condolences', 'hyderabad blast', 'pm', 'my']
# ['i', 'hope', 'the', 'police', 'do', 'a', 'professional', 'investigation', '&', 'arrest', 'people', 'base', 'on', 'real', 'evidence', '&', 'not', 'by', 'manufacturing', 'evidence', '.']
# ['i', 'hope', 'the', 'police', 'does', 'a', 'professional', 'investigation', '&', 'arrest', 'people', 'based', 'on', 'real', 'evidence', '&', 'not', 'by', 'manufacturing', 'evidence', '.']
# ['& arrest', 'base on real', 'people', 'does a professional', 'a professional', 'real evidence', 'evidence', 'professional investigation', 'based on', 'arrest people based', 'i hope', '& not', 'on real', 'people based', 'based', 'arrest people base', 'police', '& arrest people', '&', 'do a professional', '.', 'arrest', 'investigation', 'police does', 'people base on', 'professional investigation &', 'arrest people', 'hope the', 'evidence & not', 'hope', 'police do a', 'real', 'do', 'i hope the', 'manufacturing evidence .', 'police do', 'evidence .', 'people based on', 'on real evidence', 'the police does', 'hope the police', 'the police', '& not by', 'police does a', 'investigation & arrest', 'base', 'evidence &', 'not', 'the police do', 'not by manufacturing', 'manufacturing', 'by manufacturing', 'by', 'do a', 'based on real', 'a', 'on', 'manufacturing evidence', 'investigation &', 'i', 'base on', 'not by', 'real evidence &', 'does a', 'by manufacturing evidence', 'a professional investigation', 'does', 'people base', 'professional', 'the']
# ['home', 'minister', 'under', 'fire', 'over', 'hyderabad', 'blast', ',', 'bjp', 'dismiss', 'routine', 'statement', 'hindustan', 'time', '.']
# ['home', 'minister', 'under', 'fire', 'over', 'hyderabad', 'blasts', ',', 'bjp', 'dismisses', 'routine', 'statement', 'hindustan', 'times', '.']
# ['hyderabad', 'blast ,', 'hyderabad blasts', 'routine statement hindustan', 'over', 'hindustan times .', ', bjp dismisses', 'hindustan', 'bjp dismiss routine', 'bjp', 'statement hindustan times', 'home', 'bjp dismiss', 'routine statement', 'minister under', 'home minister under', 'over hyderabad', 'hyderabad blasts ,', ',', '.', 'statement hindustan', 'dismisses routine', 'minister under fire', ', bjp', 'statement', 'under', 'under fire', 'dismisses', 'over hyderabad blasts', 'statement hindustan time', 'blast , bjp', 'bjp dismisses', 'time .', 'fire', 'fire over hyderabad', 'dismiss', 'hindustan time .', 'hindustan times', 'fire over', 'minister', 'blast', 'routine', 'times', 'over hyderabad blast', 'blasts , bjp', 'blasts ,', 'dismisses routine statement', 'home minister', 'dismiss routine', 'blasts', 'bjp dismisses routine', ', bjp dismiss', 'dismiss routine statement', 'times .', 'hindustan time', 'time', 'hyderabad blast', 'hyderabad blast ,', 'under fire over']
# ['family', 'of', 'those', 'kill', 'to', 'get', 'rs', '6', 'lakh', 'each', '.']
# ['families', 'of', 'those', 'killed', 'to', 'get', 'rs', '6', 'lakhs', 'each', '.']
# ['family of', 'family of those', 'family', 'of those killed', 'of those', 'lakhs each', 'killed to', 'kill', 'those kill to', 'families of', 'lakhs', 'killed to get', 'lakh', 'of those kill', 'kill to', 'rs', '6 lakhs', 'those kill', 'lakh each', '.', 'to', 'get rs 6', 'those killed to', '6', 'those killed', 'killed', 'families of those', 'each .', 'families', 'rs 6 lakhs', 'get', 'kill to get', '6 lakh', 'to get rs', 'get rs', 'lakh each .', 'rs 6 lakh', 'to get', 'those', 'rs 6', '6 lakh each', 'lakhs each .', 'of', 'each', '6 lakhs each']
# ['screen', 'map', 'of', 'dilsukhnagar', 'hyderabad', 'blast', '.']
# ['screen', 'map', 'of', 'dilsukhnagar', 'hyderabad', 'blast', '.']
# ['map', 'of dilsukhnagar', 'dilsukhnagar', 'hyderabad', 'of', 'screen', 'dilsukhnagar hyderabad', '.', 'screen map of', 'map of dilsukhnagar', 'hyderabad blast .', 'map of', 'blast .', 'hyderabad blast', 'blast', 'screen map', 'dilsukhnagar hyderabad blast', 'of dilsukhnagar hyderabad']
# ['blast', 'report', 'in', 'hyderabad', 'if', 'you', 'be', 'at', 'the', 'blast', 'site', ',', 'feel', 'free', 'to', 'share', 'picture', 'at', 'or', '.']
# ['blast', 'reported', 'in', 'hyderabad', 'if', 'you', 'are', 'at', 'the', 'blast', 'site', ',', 'feel', 'free', 'to', 'share', 'pictures', 'at', 'or', '.']
# ['the blast site', 'hyderabad', 'if you', 'site , feel', 'blast site', 'be', 'feel', 'at or .', 'share', 'site', 'share pictures at', 'report', 'blast report in', 'at', ', feel', 'in', 'pictures at or', 'site ,', 'hyderabad if you', 'you be at', 'are', 'if', 'at the blast', 'reported in', 'feel free', ', feel free', 'pictures', 'blast site ,', ',', '.', 'to', 'are at the', 'at or', 'share pictures', 'in hyderabad', 'you', 'reported in hyderabad', 'or .', 'to share pictures', 'picture', 'free to', 'in hyderabad if', 'pictures at', 'if you are', 'free to share', 'free', 'report in hyderabad', 'reported', 'share picture at', 'at the', 'blast report', 'share picture', 'blast', 'be at the', 'if you be', 'you are at', 'blast reported', 'to share picture', 'feel free to', 'are at', 'hyderabad if', 'you be', 'picture at or', 'report in', 'you are', 'blast reported in', 'the blast', 'picture at', 'the', 'or', 'to share', 'be at']
# ['our', 'condolence', 'to', 'all', 'related', 'to', 'hyderabad', 'victim', '.']
# ['our', 'condolences', 'to', 'all', 'related', 'to', 'hyderabad', 'victims', '.']
# ['our condolence to', 'hyderabad', 'all', 'victim', 'to hyderabad victims', 'to hyderabad victim', 'related', 'victim .', 'our', 'related to hyderabad', 'to all related', 'our condolences to', 'victims .', '.', 'victims', 'to', 'to hyderabad', 'condolence', 'our condolence', 'all related to', 'hyderabad victim .', 'hyderabad victim', 'condolence to', 'our condolences', 'hyderabad victims .', 'condolence to all', 'all related', 'condolences to all', 'condolences', 'related to', 'condolences to', 'to all', 'hyderabad victims']
# ['cz', 'government', 'be', 'inept', '&', 'callous', '2', 'day', 'since', 'they', 'have', 'info', 'still', 'no', 'preventive', 'measure', '!']
# ['cz', 'government', 'is', 'inept', '&', 'callous', '2', 'days', 'since', 'they', 'had', 'info', 'still', 'no', 'preventive', 'measures', '!']
# ['no preventive', 'info still', 'cz government be', 'had info', 'had', 'they have info', 'government be', 'no preventive measures', 'since they had', 'measures !', 'cz', 'preventive measure', 'be inept &', 'have', 'measure', 'measure !', 'be inept', 'still', 'inept & callous', 'had info still', '!', 'cz government is', '2 day', 'since they', '&', '& callous 2', 'since', 'callous', 'they have', 'they had info', 'they had', '2', 'preventive measures', 'government is inept', 'is', 'info still no', 'be', 'measures', '2 days since', 'government', 'cz government', 'government is', 'inept', 'days since they', '& callous', 'preventive measure !', 'they', 'since they have', 'callous 2', 'still no preventive', 'day', 'no preventive measure', 'preventive measures !', 'info', 'days since', '2 day since', 'still no', 'is inept &', 'no', 'callous 2 days', 'days', 'day since', '2 days', 'have info', 'callous 2 day', 'have info still', 'day since they', 'preventive', 'government be inept', 'is inept', 'inept &']
# ['police', 'struggle', 'to', 'clear', 'hyderabad', 'blast', 'site', 'and', 'preserve', 'evidence', 'as', 'politician', 'jockey', 'to', 'visit', 'and', 'protester', 'pour', 'in', ',', 'ndtv', 'report', '.']
# ['police', 'struggling', 'to', 'clear', 'hyderabad', 'blast', 'site', 'and', 'preserve', 'evidence', 'as', 'politicians', 'jockey', 'to', 'visit', 'and', 'protesters', 'pour', 'in', ',', 'ndtv', 'reports', '.']
# ['congress', 'government', 'have', 'fail', 'on', 'every', 'front', '.']
# ['congress', 'government', 'has', 'failed', 'on', 'every', 'front', '.']
# ['has failed on', 'have fail on', 'front .', 'congress government has', 'has failed', 'have', 'fail', 'every front', 'failed on', '.', 'fail on', 'failed', 'has', 'government has', 'congress', 'government', 'congress government', 'every front .', 'failed on every', 'every', 'front', 'have fail', 'on', 'on every', 'fail on every', 'government have fail', 'government has failed', 'on every front', 'government have', 'congress government have']
# ['at', 'least', '11', 'kill', 'in', 'hyderabad', 'blast', '.']
# ['at', 'least', '11', 'killed', 'in', 'hyderabad', 'blasts', '.']
# ['hyderabad', 'least 11 killed', '11 killed in', 'blast .', 'in hyderabad blast', 'kill in hyderabad', 'at', 'in', 'hyderabad blasts .', 'hyderabad blasts', 'kill in', '11 kill in', 'least', '.', 'killed in', 'in hyderabad', 'killed in hyderabad', 'kill', 'least 11', '11 killed', 'hyderabad blast', 'blast', 'killed', '11', 'at least', 'at least 11', 'blasts', 'in hyderabad blasts', 'blasts .', 'least 11 kill', 'hyderabad blast .', '11 kill']
# ['india', 'will', 'emerge', 'stronger', '.']
# ['india', 'will', 'emerge', 'stronger', '.']
# ['stronger .', 'emerge', 'emerge stronger .', 'stronger', 'will emerge stronger', 'india', '.', 'will', 'india will', 'emerge stronger', 'will emerge', 'india will emerge']
# ['just', 'another', 'way', 'to', 'show', 'the', 'inefficient', 'intelligence', 'bureau', '.']
# ['just', 'another', 'way', 'to', 'show', 'the', 'inefficient', 'intelligence', 'bureau', '.']
# ['just another way', 'bureau .', 'another way to', 'intelligence bureau', 'show', 'intelligence', 'another way', 'another', 'the inefficient intelligence', 'inefficient intelligence', 'show the', 'just', 'show the inefficient', '.', 'to', 'bureau', 'way', 'way to show', 'inefficient', 'inefficient intelligence bureau', 'to show the', 'to show', 'intelligence bureau .', 'just another', 'way to', 'the inefficient', 'the']
# ['heart', 'go', 'out', 'to', 'hyderabad', 'blast', 'victim', ',', 'family', 'and', 'the', 'people', '.']
# ['heart', 'goes', 'out', 'to', 'hyderabad', 'blast', 'victims', ',', 'families', 'and', 'the', 'people', '.']
# ['and', 'heart', ', family', 'families and the', 'family', 'hyderabad', 'goes out', 'heart go', 'and the', 'out to', ', family and', 'victim ,', 'victim', 'go', 'blast victim ,', 'victims ,', 'out', 'victims , families', 'families', 'family and', ', families', 'people', ',', '.', 'victims', 'to', 'victim , family', 'the people', 'goes', 'to hyderabad', 'go out to', 'blast victim', 'family and the', 'out to hyderabad', ', families and', 'people .', 'families and', 'blast victims ,', 'hyderabad blast victims', 'blast', 'heart goes', 'heart go out', 'blast victims', 'hyderabad blast victim', 'the people .', 'heart goes out', 'to hyderabad blast', 'goes out to', 'hyderabad blast', 'the', 'go out', 'and the people']
# ['hat', 'off', 'to', 'the', 'spirit', 'of', 'hyderabad', '.']
# ['hats', 'off', 'to', 'the', 'spirit', 'of', 'hyderabad', '.']
# ['hyderabad', 'hats', 'hat off', 'hyderabad .', 'the spirit of', 'spirit of', 'the spirit', 'hats off to', 'off to the', '.', 'to', 'to the', 'hat', 'spirit of hyderabad', 'of hyderabad .', 'off to', 'hat off to', 'spirit', 'off', 'of', 'to the spirit', 'hats off', 'the', 'of hyderabad']
# ['hyderabad', 'blast', ',', 'inspect', 'cctv', 'image', '.']
# ['hyderabad', 'blast', ',', 'inspects', 'cctv', 'images', '.']
# ['inspect cctv', 'hyderabad', 'blast ,', ', inspects', 'image', 'image .', 'images', 'blast , inspect', 'inspects', 'cctv images .', ', inspects cctv', ',', '.', 'cctv images', 'inspect cctv image', 'images .', 'inspect', 'cctv', 'cctv image .', 'blast , inspects', ', inspect cctv', 'inspects cctv', ', inspect', 'blast', 'cctv image', 'inspects cctv images', 'hyderabad blast', 'hyderabad blast ,']
# ('Hydb: ', 0.8450698263437024, 0.04065367291432182)
# ('Recall', 0.8310104529616724, array([0.88095238, 0.78571429, 0.85714286, 0.83333333, 0.92857143,
#        0.73170732, 0.73170732, 0.90243902, 0.92682927, 0.73170732]))
# ('Precision', 0.8576880092545727, array([0.82222222, 0.89189189, 0.81818182, 0.8974359 , 0.78      ,
#        0.83333333, 0.83333333, 0.97368421, 0.84444444, 0.88235294]))
# ('F1', 0.8414122020198272, array([0.85057471, 0.83544304, 0.8372093 , 0.86419753, 0.84782609,
#        0.77922078, 0.77922078, 0.93670886, 0.88372093, 0.8       ]))
# ('Utkd: ', 0.7949612403100775, 0.04008323967112182)
# ('Recall', 0.765891472868217, array([0.76744186, 0.76744186, 0.81395349, 0.69767442, 0.90697674,
#        0.6744186 , 0.69767442, 0.78571429, 0.83333333, 0.71428571]))
# ('Precision', 0.8134945203847643, array([0.825     , 0.84615385, 0.83333333, 0.76923077, 0.86666667,
#        0.82857143, 0.83333333, 0.80487805, 0.77777778, 0.75      ]))
# ('F1', 0.7876228292463547, array([0.79518072, 0.80487805, 0.82352941, 0.73170732, 0.88636364,
#        0.74358974, 0.75949367, 0.79518072, 0.8045977 , 0.73170732]))
# ('SandyHook: ', 0.8993393234672306, 0.03348392098958728)
# ('Recall', 0.8956659619450317, array([0.90909091, 0.95454545, 0.8372093 , 0.93023256, 0.90697674,
#        0.8372093 , 0.81395349, 0.88372093, 0.93023256, 0.95348837]))
# ('Precision', 0.904111099685219, array([0.83333333, 0.89361702, 0.87804878, 0.93023256, 0.90697674,
#        0.85714286, 0.92105263, 1.        , 0.88888889, 0.93181818]))
# ('F1', 0.898814190399164, array([0.86956522, 0.92307692, 0.85714286, 0.93023256, 0.90697674,
#        0.84705882, 0.86419753, 0.9382716 , 0.90909091, 0.94252874]))
# ('Hagupit: ', 0.8597496947496946, 0.016930463646570013)
# ('Recall', 0.9119323671497586, array([0.93478261, 0.97826087, 0.82608696, 0.89130435, 0.97777778,
#        0.95555556, 0.84444444, 0.93333333, 0.86666667, 0.91111111]))
# ('Precision', 0.8285031422960725, array([0.84313725, 0.80357143, 0.84444444, 0.89130435, 0.78571429,
#        0.7962963 , 0.86363636, 0.80769231, 0.8125    , 0.83673469]))
# ('F1', 0.8666356128375694, array([0.88659794, 0.88235294, 0.83516484, 0.89130435, 0.87128713,
#        0.86868687, 0.85393258, 0.86597938, 0.83870968, 0.87234043]))
# Train Hydb
# ('Utkd: ', 0.7833723653395784)
# ('Sandy_Hook: ', 0.8946759259259259)
# ('Hagupit: ', 0.8123620309050773)
# Train Utkd
# ('Hydb: ', 0.8269230769230769)
# ('Sandy_Hook: ', 0.8981481481481481)
# ('Hagupit: ', 0.804635761589404)
# Train Sandy_Hook
# ('Hydb: ', 0.8341346153846154)
# ('Utkd: ', 0.7845433255269321)
# ('Hagupit: ', 0.7935982339955849)
# Train Hagupit
# ('Hydb: ', 0.8064903846153846)
# ('Utkd: ', 0.7693208430913349)
# ('Sandy_Hook: ', 0.8912037037037037)
#
#
#
# Hydb -> utkd | sandy_hook | hagupit
# ('PRECISION: ', 0.8252688172043011)
# ('RECALL: ', 0.7189695550351288)
# ('F1_SCORE: ', 0.7684605757196497)
# ('PRECISION: ', 0.929471032745592)
# ('RECALL: ', 0.8541666666666666)
# ('F1_SCORE: ', 0.8902291917973462)
# ('PRECISION: ', 0.8756613756613757)
# ('RECALL: ', 0.7290748898678414)
# ('F1_SCORE: ', 0.7956730769230769)
#
#
#
# Utkd -> hydb | sandy_hook | hagupit
# ('PRECISION: ', 0.8188235294117647)
# ('RECALL: ', 0.8385542168674699)
# ('F1_SCORE: ', 0.8285714285714285)
# ('PRECISION: ', 0.9215686274509803)
# ('RECALL: ', 0.8703703703703703)
# ('F1_SCORE: ', 0.8952380952380952)
# ('PRECISION: ', 0.8353510895883777)
# ('RECALL: ', 0.7599118942731278)
# ('F1_SCORE: ', 0.7958477508650518)
#
#
#
# Sandy_hook -> hydb | utkd | hagupit
# ('PRECISION: ', 0.8183908045977012)
# ('RECALL: ', 0.8578313253012049)
# ('F1_SCORE: ', 0.8376470588235295)
# ('PRECISION: ', 0.7970660146699267)
# ('RECALL: ', 0.7634660421545667)
# ('F1_SCORE: ', 0.7799043062200957)
# ('PRECISION: ', 0.8186157517899761)
# ('RECALL: ', 0.7555066079295154)
# ('F1_SCORE: ', 0.7857961053837342)
#
#
#
# Hagupit -> hydb | utkd | sandy_hook
# ('PRECISION: ', 0.7529880478087649)
# ('RECALL: ', 0.9108433734939759)
# ('F1_SCORE: ', 0.8244274809160306)
# ('PRECISION: ', 0.733739837398374)
# ('RECALL: ', 0.8454332552693209)
# ('F1_SCORE: ', 0.7856365614798696)
# ('PRECISION: ', 0.8823529411764706)
# ('RECALL: ', 0.9027777777777778)
# ('F1_SCORE: ', 0.8924485125858124)
# (4, 12, 12, 12, 12)
# ('Average Indomain Accuracy: ', 0.8497800212176763)
# ('Average Cross-domain Accuracy: ', 0.8249507012623972)
# ('Average and std Precision: ', 0.8341081557919671, 0.05746330828034784)
# ('Average and std Recall: ', 0.8172421645839139, 0.06492358199169386)
# ('Average and std F-score: ', 0.8233233453769766, 0.04463137167492172)
